# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_udemy_courses = pd.read_csv(r'Moocs\udemy_courses.csv', encoding='utf-8')

# %%
df_udemy_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
df_udemy_courses.drop_duplicates(subset='course_id', inplace=True)

# %%
df_udemy_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   bool
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   object
#  11  subject              3672 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 347.8+ KB

# %%
#Conversión a variables categoricas
df_udemy_courses.course_id=df_udemy_courses.course_id.astype('category')
df_udemy_courses.course_title=df_udemy_courses.course_title.astype('category')
df_udemy_courses.url=df_udemy_courses.url.astype('category')
df_udemy_courses.level=df_udemy_courses.level.astype('category')
df_udemy_courses.subject=df_udemy_courses.subject.astype('category')
df_udemy_courses['published_timestamp'] = pd.to_datetime(df_udemy_courses['published_timestamp'])

# %%
df_udemy_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   category
#  1   course_title         3672 non-null   category
#  2   url                  3672 non-null   category
#  3   is_paid              3672 non-null   bool
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   category
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   datetime64[ns, UTC]
#  11  subject              3672 non-null   category
# dtypes: bool(1), category(5), datetime64[ns, UTC](1), float64(1), int64(4)
# memory usage: 706.6 KB

# %%
df_udemy_courses.course_title.value_counts()
# Out:
# course_title
# Creating an animated greeting card via Google Slides           3
# Acoustic Blues Guitar Lessons                                  3
# Aprende a tocar el acordeón de botones                         2
# Introduction to Web Development                                2
# How to Make a Wordpress Website 2017                           2
#                                                               ..
# Financial analysis: Compare performance of companies           1
# Financial and Business Simulation with Microsoft Excel         1
# Financial modeling: Build a DCF equity valuation model         1
# Financial modeling: Build a forward looking financial model    1
# ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー                     1
# Name: count, Length: 3663, dtype: int64

# %%
df_udemy_courses.course_id.unique()
# Out:
# [1070968, 1113822, 1006314, 1210588, 1011058, ..., 775618, 1088178, 635248, 905096, 297602]
# Length: 3672
# Categories (3672, int64): [8324, 8325, 11153, 11174, ..., 1276182, 1276364, 1277924, 1282064]

# %%
df_udemy_courses.course_title.unique()
# Out:
# ['Ultimate Investment Banking Course', 'Complete GST Course & Certification - Grow Yo..., 'Financial Modeling for Business Analysts and ..., 'Beginner to Pro - Financial Analysis in Excel..., 'How To Maximize Your Profits Trading Options', ..., 'Learn jQuery from Scratch - Master of JavaScr..., 'How To Design A WordPress Website With No Cod..., 'Learn and Build using Polymer', 'CSS Animations: Create Amazing Effects on You..., 'Using MODX CMS to Build Websites: A Beginner'...]
# Length: 3663
# Categories (3663, object): ['#1 Piano Hand Coordination: Play 10th Ballad ..., '#10 Hand Coordination - Transfer Chord Ballad..., '#12 Hand Coordination: Let your Hands dance w..., '#4 Piano Hand Coordination: Fun Piano Runs in..., ..., '超基礎！超入門！〜作りながら学ぶ。完全無料3DCGソフトBlender〜', '캔바(Canva)로 SNS 콘텐츠 만들기', '６時間でインターバンク市場を攻略！最短距離でトレード基礎力', '７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー']

# %%
df_udemy_courses.head()
# Out:
#   course_id                                       course_title  \
# 0   1070968                 Ultimate Investment Banking Course
# 1   1113822  Complete GST Course & Certification - Grow You...
# 2   1006314  Financial Modeling for Business Analysts and C...
# 3   1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4   1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df_udemy_courses.describe()
# Out:
#              price  num_subscribers   num_reviews  num_lectures  \
# count  3672.000000      3672.000000   3672.000000   3672.000000
# mean     66.102941      3190.586874    156.371460     40.140251
# std      61.035920      9488.105448    936.178649     50.417102
# min       0.000000         0.000000      0.000000      0.000000
# 25%      20.000000       111.750000      4.000000     15.000000
# 50%      45.000000       912.000000     18.000000     25.000000
# 75%      95.000000      2548.750000     67.000000     46.000000
# max     200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3672.000000
# mean           4.097603
# std            6.057830
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %% [markdown]
# Genro el fragico de tendencia de los cursos pagos vs los no pagos para el dataset Udemy, observando mayor tendencia a cursos pagos.

# %%
import seaborn as sns
# Se observa la distribucion de la variable categorica level para observar la tendencia 
sns.countplot(x='is_paid', data=df_udemy_courses)
# Out:
# <Axes: xlabel='is_paid', ylabel='count'>

# %% [markdown]
# Se observa la tendencia de la variable categorica level del portafolio de cursos online, la tendencia muestra mayor concentraciòn en los cursos para todos los niveles.

# %%
import seaborn as sns
# Se observa la tendencia de la variable categorica level, permite identificar la tendencia del portafolio de cursos online 
sns.countplot(x='level', data=df_udemy_courses)
# Out:
# <Axes: xlabel='level', ylabel='count'>

# %% [markdown]
# En el histograma price podemos obbservar la distribuciòn de la variable price, se logra identificar visualmente que en el precio aproximado de 25 se encuentran alrededor de 800 cursos (frecuencia).

# %%
# Graficar el histograma
sns.histplot(data=df_udemy_courses, x='price')

# Configurar etiquetas y título del gráfico
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of price')
plt.show()

# %% [markdown]
# En el histograma lectures de los cursos ofrecidos se evidencia una mayor frecuencia en los cursos que tienen menos de 50 lecciones.

# %%
# Graficar el histograma
sns.histplot(data=df_udemy_courses, x='num_lectures')

# Configurar etiquetas y título del gráfico
plt.xlabel('num_lectures')
plt.ylabel('Frequency')
plt.title('Histogram of num_lectures')
plt.show()

# %% [markdown]
# En el histograma de horas de duraciòn  se evicencia un mayor frecuencia en los cursos de duraciòn de 0 a 10 horas.

# %%
# Graficar el histograma
sns.histplot(data=df_udemy_courses, x='content_duration')

# Configurar etiquetas y título del gráfico
plt.xlabel('content_duration')
plt.ylabel('Frequency')
plt.title('Histogram of content_duration')
plt.show()

# %% [markdown]
# La mayor frecuencia de publicaciòn de cursos se observa en el año 2017

# %%
# Graficar el histograma
sns.histplot(data=df_udemy_courses, x='published_timestamp')

# Configurar etiquetas y título del gráfico
plt.xlabel('published_timestamp')
plt.ylabel('Frequency')
plt.title('Histogram of published_timestamp')
plt.show()

# %%
#Tabla pivote que permite observar el comportamiento en cada uno de los grupos level / subscriptores promedio
pd.pivot_table(df_udemy_courses, index='level', values='num_subscribers', aggfunc='mean')
# Out:
#                     num_subscribers
# level
# All Levels              3569.761558
# Beginner Level          3195.459779
# Expert Level             865.448276
# Intermediate Level      1762.482185

# %%
#Tabla pivote que permite observar el comportamiento en cada uno de los grupos subject / subscriptores promedio
pd.pivot_table(df_udemy_courses, index='subject', values='num_subscribers', aggfunc='mean')
# Out:
#                      num_subscribers
# subject
# Business Finance         1569.026868
# Graphic Design           1766.026578
# Musical Instruments      1245.130882
# Web Development          6619.922435

# %%
pv1=pd.pivot_table(df_udemy_courses, index='subject', values='num_subscribers', aggfunc='mean')

# %%
pv1.plot.bar()
# Out:
# <Axes: xlabel='subject'>

# %%
#Tabla pivote que permite observar el comportamiento en cada uno de los grupos level / precio promedio
pd.pivot_table(df_udemy_courses, index='level', values='price', aggfunc='mean')
# Out:
#                         price
# level
# All Levels          73.090909
# Beginner Level      55.737382
# Expert Level        91.120690
# Intermediate Level  61.923990

# %%
sns.boxplot(data=df_udemy_courses, y='price', x='level', hue='subject')
# Out:
# <Axes: xlabel='level', ylabel='price'>

# %%
sns.scatterplot(data=df_udemy_courses, x='price', y='num_subscribers')
# Out:
# <Axes: xlabel='price', ylabel='num_subscribers'>

# %%
sns.scatterplot(data=df_udemy_courses, x='price', y='content_duration')
# Out:
# <Axes: xlabel='price', ylabel='content_duration'>

# %%
df_udemy_courses['year']=df_udemy_courses['published_timestamp'].dt.year
df_udemy_courses['month']=df_udemy_courses['published_timestamp'].dt.month

# %%
sns.scatterplot(data=df_udemy_courses, x='year', y='price')
#Se observa estabilidad en los precios del 2014 al 2017
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
sns.scatterplot(data=df_udemy_courses, x='year', y='num_subscribers')
#Se observa un decrecimiento entre el 2017 y 2016
# Out:
# <Axes: xlabel='year', ylabel='num_subscribers'>

# %%
df_udemy_courses1 = df_udemy_courses[['price', 'num_subscribers', 'num_reviews', 'num_lectures', 'content_duration']]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = df_udemy_courses1.corr()

ax = sns.heatmap(
    corr_matrix, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot=True,  # Agregar valores en cada recuadro
    fmt=".2f"  # Formato de los valores (2 decimales)
)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# Descargar las stopwords si no están disponibles
nltk.download('stopwords')

# Obtener los títulos del DataFrame
titulos = df_udemy_courses['course_title']

# Unir todos los títulos en un solo texto
texto = ' '.join(titulos)

# Tokenizar el texto en palabras
tokens = word_tokenize(texto)

# Obtener las stopwords en el idioma deseado (en este caso, inglés)
stop_words = set(stopwords.words('english'))

# Filtrar las stopwords del texto
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

# Unir los tokens filtrados en un solo texto
filtered_text = ' '.join(filtered_tokens)

# Crear el objeto WordCloud
wordcloud = WordCloud(width=800, height=400, max_words=100, background_color='white').generate(filtered_text)

# Mostrar el WordCloud en una figura
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WordCloud de los Títulos')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_udemy_courses.head()
# Out:
#   course_id                                       course_title  \
# 0   1070968                 Ultimate Investment Banking Course
# 1   1113822  Complete GST Course & Certification - Grow You...
# 2   1006314  Financial Modeling for Business Analysts and C...
# 3   1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4   1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df_udemy_courses.to_csv('udemy_coursesEDA.csv', index=False)

# %%
total_subscribers_paid = df_udemy_courses.loc[df_udemy_courses['is_paid'] == True, 'num_subscribers'].sum()
total_subscribers_no_paid= df_udemy_courses.loc[df_udemy_courses['is_paid'] == False, 'num_subscribers'].sum()

tasa_coversion=(total_subscribers_paid/total_subscribers_no_paid)*100

print(f'pagos: {total_subscribers_paid}, no_pagos {total_subscribers_no_paid}, tasa_conversion: {tasa_coversion}')
# Out:
# pagos: 8140310, no_pagos 3575525, tasa_conversion: 227.66754532551167

# %%
# 119028 2011
# 555339 2012
# 1680153  2013
# 1932261 2014
# 3473469 2015
# 2966644 2016
# 988941 2017

año_actual= 988941
año_anterior=2966644

crecimiento=(año_actual-año_anterior)/año_anterior
crecimiento
# Out:
# -0.6666465541534474

# %%
año_actual= 1137000
año_anterior=988941

crecimiento=((año_actual-año_anterior)/año_anterior)
crecimiento
# Out:
# 14.97146948099027
